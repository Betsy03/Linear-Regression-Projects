# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error

# %%
salary=pd.read_csv("A:/Data Science/assignments/Linear Regression/Salary_Data.csv")

# %%
salary.shape
# Out:
# (30, 2)

# %%
salary.columns
# Out:
# Index(['YearsExperience', 'Salary'], dtype='object')

# %%
salary.describe()
# Out:
#        YearsExperience         Salary
# count        30.000000      30.000000
# mean          5.313333   76003.000000
# std           2.837888   27414.429785
# min           1.100000   37731.000000
# 25%           3.200000   56720.750000
# 50%           4.700000   65237.000000
# 75%           7.700000  100544.750000
# max          10.500000  122391.000000

# %%
sns.heatmap(salary.corr())

# %%
salary.corr()
# Out:
#                  YearsExperience    Salary
# YearsExperience         1.000000  0.978242
# Salary                  0.978242  1.000000

# %%
sns.relplot(x='Salary',y='YearsExperience',data=salary,kind="scatter")

# %%
sal_x=salary.YearsExperience
sal_y=salary.Salary

# %%
X_train,X_test,Y_train,Y_test=train_test_split(sal_x,sal_y,test_size=0.2,random_state=10)

# %%
X_train=X_train.values.reshape(-1,1)
Y_train=Y_train.values.reshape(-1,1)
X_test=X_test.values.reshape(-1,1)
Y_test=Y_test.values.reshape(-1,1)

# %%
sal_reg=LinearRegression()
sal_model=sal_reg.fit(X_train,Y_train)

# %%
sal_predict=sal_model.predict(X_test)

# %%
sal_score=sal_model.score(X_test,Y_test)

# %%
print(sal_score)
# Out:
# 0.9816423482070255

# %%
plt.plot(salary.YearsExperience,salary.Salary)
plt.scatter(X_test,sal_predict)

# %%
sal_model.intercept_
# Out:
# array([26089.09663242])

# %%
#Results
#Accuracy score is 98%
